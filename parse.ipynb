# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import pandas as pd
from IPython.display import display

# %%
def get_apartment_links(page_url):
    """Збирає посилання на всі квартири з однієї сторінки пошуку."""
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'}
    response = requests.get(page_url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    links = set()
    elements = soup.find_all(attrs={"data-event-options": re.compile(r"page_id:\d+")})
    for el in elements:
        match = re.search(r'page_id:(\d+)', el.get('data-event-options', ''))
        if match:
            links.add(f"https://lun.ua/realty/{match.group(1)}")
            
    return list(links)


def parse_apartment_data(url):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'}
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Структура БЕЗ building_details, але З гео-координатами та районом
    data = {
        'url': url, 'price': None, 'currency': None, 'address': None, 'rooms': None, 
        'area_total': None, 'area_living': None, 'area_kitchen': None,
        'floor': None, 'total_floors': None, 
        'build_year': None, 'construction_tech': None, 'heating_type': None,
        'lat': None, 'lon': None, 'district': None, # Гео-дані з ЛУН
        'commission': None, 'description': None
    }
    
    tech_mapping = {
        'моноліт': 'монолітно-каркасна',
        'утеплена панель': 'утеплена панель',
        'панель': 'панельна технологія',
        'цегл': 'цегляна технологія',
        'блок': 'блочна технологія',
        'блочн': 'блочна технологія'
    }
    
    # 1. ЦІНА ТА ВАЛЮТА
    raw_price = None
    price_tag = soup.find(class_=re.compile("RealtyDetails_priceMain|RealtyCard_price"))
    if price_tag:
        raw_price = price_tag.text.strip()
    else:
        og_title = soup.find("meta", property="og:title")
        title_text = og_title["content"] if og_title else (soup.title.text if soup.title else "")
        if title_text:
            price_match = re.search(r'((?:[\$€]\s*)?[\d\s\u202f\u200a]+(?:грн|\$|€)?)', title_text)
            if price_match: 
                raw_price = price_match.group(1).strip()

    if raw_price:
        raw_price_lower = raw_price.lower()
        if '$' in raw_price_lower: data['currency'] = 'USD'
        elif '€' in raw_price_lower: data['currency'] = 'EUR'
        elif 'грн' in raw_price_lower: data['currency'] = 'UAH'
            
        clean_price = re.sub(r'[^\d]', '', raw_price)
        if clean_price: data['price'] = clean_price

    # 2. АДРЕСА
    address_tag = soup.find(class_=re.compile("RealtyDetails_address|Realty_address"))
    if address_tag: data['address'] = address_tag.text.strip()

    # 3. ОПИС
    desc_tag = soup.find("article") or soup.find(attrs={"itemprop": "description"}) or soup.find(class_=re.compile("description|Description|ExpandableText_text"))
    if desc_tag: data['description'] = desc_tag.text.strip()
    
    # 4. КОМІСІЯ (Лейбли)
    labels = soup.find_all(class_=re.compile("LabelRefresh-module_content|LabelList_label"))
    for label in labels:
        if 'без комісії' in label.text.lower():
            data['commission'] = 'без комісії'
            break

    # 5. ХАРАКТЕРИСТИКИ
    temp_details = [] # тимчасовий список для перевірки дублікатів
    properties = soup.find_all(class_=re.compile("PropertyItem|Characteristic|param"))
    for prop in properties:
        text = prop.text.strip()
        if not text or text in temp_details: continue
        temp_details.append(text)
        
        text_lower = text.lower()
        
        # Комісія
        if 'комісі' in text_lower and not data['commission']:
            if 'без' in text_lower: data['commission'] = 'без комісії'
            elif '%' in text_lower or re.search(r'\d+', text_lower): data['commission'] = text
        
        # Кімнати
        if 'кімнат' in text_lower and not data['rooms']: 
            rooms_match = re.search(r'\d+', text)
            if rooms_match: data['rooms'] = rooms_match.group(0)
                
        # Площа
        elif 'м²' in text and not data['area_total']: 
            area_clean = text.replace('м²', '').strip()
            area_parts = [p.strip() for p in area_clean.split('/')]
            if len(area_parts) >= 1: data['area_total'] = area_parts[0]
            if len(area_parts) >= 2: data['area_living'] = area_parts[1]
            if len(area_parts) >= 3: data['area_kitchen'] = area_parts[2]
                
        # Поверх
        elif 'поверх' in text_lower and not data['floor']:
            floor_match = re.search(r'поверх (\d+) з (\d+)', text)
            if floor_match:
                data['floor'] = floor_match.group(1)
                data['total_floors'] = floor_match.group(2)
            else:
                data['floor'] = text
                
        # Рік будівництва
        elif 'рік будівництва' in text_lower or 'рік побудови' in text_lower:
            year_match = re.search(r'\d{4}', text)
            if year_match: data['build_year'] = year_match.group(0)
                
        # Тип опалення 
        elif 'опалення' in text_lower and 'без світла' not in text_lower:
            data['heating_type'] = text
            
        # Технологія будівництва
        if not data['construction_tech']:
            for key, exact_value in tech_mapping.items():
                if key in text_lower:
                    if key == 'панель' and 'утеплена панель' in text_lower: continue 
                    data['construction_tech'] = exact_value
                    break

    # 6. Резервний пошук в описі
    if data['description']:
        desc_lower = data['description'].lower()
        if not data['commission']:
            comm_match = re.search(r'(?i)(?:комісі|комісійні).*?(\d+\s*%|без комісії)', data['description'])
            if comm_match: data['commission'] = comm_match.group(0)
                
        if not data['construction_tech']:
            for key, exact_value in tech_mapping.items():
                if key in desc_lower:
                    if key == 'панель' and 'утеплена панель' in desc_lower: continue 
                    data['construction_tech'] = exact_value
                    break

    # 7. ГЕО-ДАНІ (Координати та Район безпосередньо з коду ЛУН)
    html_str = response.text
    
    # ЛУН записує координати як "location":[longitude, latitude]
    location_match = re.search(r'(?:\\"|")location(?:\\"|")\s*:\s*\[\s*([\d\.]+)\s*,\s*([\d\.]+)\]', html_str)
    if location_match:
        data['lon'] = location_match.group(1)
        data['lat'] = location_match.group(2)
        
    # Район визначається через супутню геолокаційну сутність
    district_match = re.search(r'(?:\\"|")name(?:\\"|")\s*:\s*(?:\\"|")([^"\\]+)(?:\\"|"),\s*(?:\\"|")realtyGeoUrl(?:\\"|").*?-district', html_str)
    if district_match:
        data['district'] = district_match.group(1)

    # 8. ОЧИЩЕННЯ ТЕКСТУ ВІД ПЕРЕНОСІВ (БЕЗ building_details)
    for key in ['address', 'description', 'commission', 'heating_type']:
        if data[key]:
            clean_text = re.sub(r'[\n\r\t]+', ' ', data[key])
            data[key] = re.sub(r'\s+', ' ', clean_text).strip()
            
    return data

def run_scraper(pages_list, limit_flats=None):
    """
    Головна функція. Приймає список сторінок і повертає готовий DataFrame.
    limit_flats - обмежує кількість зібраних квартир для тестів (напр. 5).
    """
    all_links = []
    print("Шукаємо посилання на квартири...")
    for page in pages_list:
        links = get_apartment_links(page)
        all_links.extend(links)
        print(f"Знайдено {len(links)} на {page}")
        time.sleep(0.1) 
        
    unique_links = list(set(all_links))
    if limit_flats:
        unique_links = unique_links[:limit_flats]
        
    print(f"\nПочинаємо збір даних по {len(unique_links)} квартирах...")
    scraped_data = []
    
    for i, link in enumerate(unique_links):
        print(f"[{i+1}/{len(unique_links)}] {link}")
        scraped_data.append(parse_apartment_data(link))
        time.sleep(0.3)
        
    print("\nГотово!")
    return pd.DataFrame(scraped_data)

# %%
# ==========================================
# ЗАПУСК КОДУ: ПАРСИНГ ІЗ ЗБЕРЕЖЕННЯМ КОЖНІ 300
# ==========================================
base_url = "https://lun.ua/rent/kyiv/flats"
output_csv = "kyiv_flats_data.csv"
save_interval = 300

# 1. Перевіряємо, чи є вже збережені дані
scraped_urls = set()
if os.path.exists(output_csv):
    existing_df = pd.read_csv(output_csv)
    scraped_urls = set(existing_df['url'].tolist())
    print(f"Знайдено файл збереження. Вже зібрано квартир: {len(scraped_urls)}")

# 2. Шукаємо всі посилання на всіх сторінках
all_links = []
page = 1
print("Шукаємо посилання на сайті...")

while True:
    url = base_url if page == 1 else f"{base_url}?page={page}"
    print(f"Перевіряю сторінку {page}...", end='\r')
    
    links = get_apartment_links(url)
    if not links:
        print(f"\nКвартири закінчились на сторінці {page-1}.")
        break
        
    all_links.extend(links)
    page += 1
    time.sleep(0.4)

unique_links = list(set(all_links))
print(f"\nВсього знайдено посилань на сайті: {len(unique_links)}")

# 3. Відфільтровуємо тільки нові квартири
links_to_scrape = [link for link in unique_links if link not in scraped_urls]
print(f"Нових квартир для парсингу: {len(links_to_scrape)}")

# 4. Парсимо і зберігаємо порціями
batch_data = []

# Для швидкого тесту можеш розкоментувати рядок нижче:
# links_to_scrape = links_to_scrape[:5] 

for i, link in enumerate(links_to_scrape):
    print(f"[{i+1}/{len(links_to_scrape)}] {link}")
    
    try:
        flat_data = parse_apartment_data(link)
        batch_data.append(flat_data)
    except Exception as e:
        print(f"Помилка при парсингу {link}: {e}")
        
    time.sleep(0.5)
    
    # Автозбереження кожні 300 або якщо це остання квартира в списку
    is_last = (i == len(links_to_scrape) - 1)
    if len(batch_data) == save_interval or is_last:
        df_batch = pd.DataFrame(batch_data)
        
        # Якщо файлу нема - пишемо з заголовками, якщо є - дописуємо (append)
        file_exists = os.path.exists(output_csv)
        df_batch.to_csv(output_csv, mode='a', index=False, header=not file_exists, encoding='utf-8-sig')
        
        print(f"\n[АВТОЗБЕРЕЖЕННЯ] {len(batch_data)} нових квартир додано у {output_csv}!\n")
        batch_data = [] # Очищаємо порцію для наступних

print("\nЗбір даних завершено!")

# Щоб подивитись результат прямо в Jupyter:
if os.path.exists(output_csv):
    display(pd.read_csv(output_csv).head())
# Out:
# Знайдено файл збереження. Вже зібрано квартир: 9515
# Шукаємо посилання на сайті...
# Перевіряю сторінку 410...
# Квартири закінчились на сторінці 409.
#
# Всього знайдено посилань на сайті: 8425
# Нових квартир для парсингу: 848
# [1/848] https://lun.ua/realty/4695721686
# [2/848] https://lun.ua/realty/4675137903
# [3/848] https://lun.ua/realty/4693754410
# [4/848] https://lun.ua/realty/4696070017
# [5/848] https://lun.ua/realty/4696275415
# [6/848] https://lun.ua/realty/4696060402
# [7/848] https://lun.ua/realty/4272713296
# [8/848] https://lun.ua/realty/4667043789
# [9/848] https://lun.ua/realty/4696151889
# [10/848] https://lun.ua/realty/4695669125
# [11/848] https://lun.ua/realty/4560355888
# [12/848] https://lun.ua/realty/4587705262
# [13/848] https://lun.ua/realty/4695814075
# [14/848] https://lun.ua/realty/4695215098
# [15/848] https://lun.ua/realty/4695485984
# [16/848] https://lun.ua/realty/4696373052
# [17/848] https://lun.ua/realty/4375568855
# [18/848] https://lun.ua/realty/4460456586
# [19/848] https://lun.ua/realty/4695456704
# [20/848] https://lun.ua/realty/4695622013
# [21/848] https://lun.ua/realty/4694938710
# [22/848] https://lun.ua/realty/4695988442
# [23/848] https://lun.ua/realty/4696267045
# [24/848] https://lun.ua/realty/4694914373
# [25/848] https://lun.ua/realty/4696288251
# [26/848] https://lun.ua/realty/4695486801
# [27/848] https://lun.ua/realty/4533982042
# [28/848] https://lun.ua/realty/4695907708
# [29/848] https://lun.ua/realty/4696266513
# [30/848] https://lun.ua/realty/4696288299
# [31/848] https://lun.ua/realty/4695907700
# [32/848] https://lun.ua/realty/4407213024
# [33/848] https://lun.ua/realty/4695457044
# [34/848] https://lun.ua/realty/4695469071
# [35/848] https://lun.ua/realty/4688211433
# [36/848] https://lun.ua/realty/4695477305
# [37/848] https://lun.ua/realty/4695655539
# [38/848] https://lun.ua/realty/4134136795
# [39/848] https://lun.ua/realty/4454826216
# [40/848] https://lun.ua/realty/4695988418
# [41/848] https://lun.ua/realty/4600160980
# [42/848] https://lun.ua/realty/4661648131
# [43/848] https://lun.ua/realty/4609230702
# [44/848] https://lun.ua/realty/4696117681
# [45/848] https://lun.ua/realty/4462157422
# [46/848] https://lun.ua/realty/4364492364
# [47/848] https://lun.ua/realty/4497139513
# [48/848] https://lun.ua/realty/4318688196
# [49/848] https://lun.ua/realty/4640775175
# [50/848] https://lun.ua/realty/4696335754
# [51/848] https://lun.ua/realty/4695860634
# [52/848] https://lun.ua/realty/4533053835
# [53/848] https://lun.ua/realty/4547771047
# [54/848] https://lun.ua/realty/4696351359
# [55/848] https://lun.ua/realty/4356287112
# [56/848] https://lun.ua/realty/4695729577
# [57/848] https://lun.ua/realty/4696231658
# [58/848] https://lun.ua/realty/4695694196
# [59/848] https://lun.ua/realty/4695988419
# [60/848] https://lun.ua/realty/4515505184
# [61/848] https://lun.ua/realty/4694969494
# [62/848] https://lun.ua/realty/4654636246
# [63/848] https://lun.ua/realty/4695803793
# [64/848] https://lun.ua/realty/4406702041
# [65/848] https://lun.ua/realty/4695787995
# [66/848] https://lun.ua/realty/4666286031
# [67/848] https://lun.ua/realty/4696081204
# [68/848] https://lun.ua/realty/4603399594
# [69/848] https://lun.ua/realty/4404544402
# [70/848] https://lun.ua/realty/4667556888
# [71/848] https://lun.ua/realty/4696331049
# [72/848] https://lun.ua/realty/4649036465
# [73/848] https://lun.ua/realty/4695787407
# [74/848] https://lun.ua/realty/4696034240
# [75/848] https://lun.ua/realty/4695456940
# [76/848] https://lun.ua/realty/4639283034
# [77/848] https://lun.ua/realty/4695705460
# [78/848] https://lun.ua/realty/4696125924
# [79/848] https://lun.ua/realty/4695988407
# [80/848] https://lun.ua/realty/4532983569
# [81/848] https://lun.ua/realty/4695470771
# [82/848] https://lun.ua/realty/4695838313
# [83/848] https://lun.ua/realty/4560370675
# [84/848] https://lun.ua/realty/4631463276
# [85/848] https://lun.ua/realty/4621227427
# [86/848] https://lun.ua/realty/4695471704
# [87/848] https://lun.ua/realty/4695521153
# [88/848] https://lun.ua/realty/4695611015
# [89/848] https://lun.ua/realty/4680930806
# [90/848] https://lun.ua/realty/4696266536
# [91/848] https://lun.ua/realty/4536581899
# [92/848] https://lun.ua/realty/3780377102
# [93/848] https://lun.ua/realty/4681323991
# [94/848] https://lun.ua/realty/4469955214
# [95/848] https://lun.ua/realty/4688804075
# [96/848] https://lun.ua/realty/4625178223
# [97/848] https://lun.ua/realty/4451656982
# [98/848] https://lun.ua/realty/4679652917
# [99/848] https://lun.ua/realty/4696106839
# [100/848] https://lun.ua/realty/4696305224
# [101/848] https://lun.ua/realty/4695672596
# [102/848] https://lun.ua/realty/4680145279
# [103/848] https://lun.ua/realty/4676151203
# [104/848] https://lun.ua/realty/4497061001
# [105/848] https://lun.ua/realty/3775120160
# [106/848] https://lun.ua/realty/4695670109
# [107/848] https://lun.ua/realty/4695487264
# [108/848] https://lun.ua/realty/4695454931
# [109/848] https://lun.ua/realty/4692046126
# [110/848] https://lun.ua/realty/4695604555
# [111/848] https://lun.ua/realty/4447859082
# [112/848] https://lun.ua/realty/4588936808
# [113/848] https://lun.ua/realty/4618029444
# [114/848] https://lun.ua/realty/3168162715
# [115/848] https://lun.ua/realty/4695456878
# [116/848] https://lun.ua/realty/4695755166
# [117/848] https://lun.ua/realty/4695469052
# [118/848] https://lun.ua/realty/4696336210
# [119/848] https://lun.ua/realty/4577011712
# [120/848] https://lun.ua/realty/4695526557
# [121/848] https://lun.ua/realty/4257150464
# [122/848] https://lun.ua/realty/4227409626
# [123/848] https://lun.ua/realty/4695705757
# [124/848] https://lun.ua/realty/4695743984
# [125/848] https://lun.ua/realty/4695606490
# [126/848] https://lun.ua/realty/4666267096
# [127/848] https://lun.ua/realty/4694951463
# [128/848] https://lun.ua/realty/4695456881
# [129/848] https://lun.ua/realty/4695611372
# [130/848] https://lun.ua/realty/4402343450
# [131/848] https://lun.ua/realty/4696078634
# [132/848] https://lun.ua/realty/4683502339
# [133/848] https://lun.ua/realty/4215795498
# [134/848] https://lun.ua/realty/4695838338
# [135/848] https://lun.ua/realty/4692570942
# [136/848] https://lun.ua/realty/4676299319
# [137/848] https://lun.ua/realty/4695456942
# [138/848] https://lun.ua/realty/4696348144
# [139/848] https://lun.ua/realty/4696373594
# [140/848] https://lun.ua/realty/4608301510
# [141/848] https://lun.ua/realty/4696082683
# [142/848] https://lun.ua/realty/4695567958
# [143/848] https://lun.ua/realty/4670703538
# [144/848] https://lun.ua/realty/4637174131
# [145/848] https://lun.ua/realty/4667796459
# [146/848] https://lun.ua/realty/4695655534
# [147/848] https://lun.ua/realty/4696256474
# [148/848] https://lun.ua/realty/4695731023
# [149/848] https://lun.ua/realty/4696304098
# [150/848] https://lun.ua/realty/4541323165
# [151/848] https://lun.ua/realty/4516053530
# [152/848] https://lun.ua/realty/4643202076
# [153/848] https://lun.ua/realty/4695731024
# [154/848] https://lun.ua/realty/4695489933
# [155/848] https://lun.ua/realty/2306800243
# [156/848] https://lun.ua/realty/4336110373
# [157/848] https://lun.ua/realty/4695584012
# [158/848] https://lun.ua/realty/4519746402
# [159/848] https://lun.ua/realty/4580838900
# [160/848] https://lun.ua/realty/4517364487
# [161/848] https://lun.ua/realty/4657840207
# [162/848] https://lun.ua/realty/4695988404
# [163/848] https://lun.ua/realty/4695752904
# [164/848] https://lun.ua/realty/4629044479
# [165/848] https://lun.ua/realty/4533264780
# [166/848] https://lun.ua/realty/4531949538
# [167/848] https://lun.ua/realty/4695743345
# [168/848] https://lun.ua/realty/4695455063
# [169/848] https://lun.ua/realty/4667584840
# [170/848] https://lun.ua/realty/4540701917
# [171/848] https://lun.ua/realty/4536224352
# [172/848] https://lun.ua/realty/4593222260
# [173/848] https://lun.ua/realty/4695487149
# [174/848] https://lun.ua/realty/4695474930
# [175/848] https://lun.ua/realty/4695582474
# [176/848] https://lun.ua/realty/4655938616
# [177/848] https://lun.ua/realty/4695174066
# [178/848] https://lun.ua/realty/4695457016
# [179/848] https://lun.ua/realty/4694768635
# [180/848] https://lun.ua/realty/4616699181
# [181/848] https://lun.ua/realty/4051797209
# [182/848] https://lun.ua/realty/4671347073
# [183/848] https://lun.ua/realty/4696094682
# [184/848] https://lun.ua/realty/4133327739
# [185/848] https://lun.ua/realty/4676125156
# [186/848] https://lun.ua/realty/4696010790
# [187/848] https://lun.ua/realty/4696298581
# [188/848] https://lun.ua/realty/4695456877
# [189/848] https://lun.ua/realty/4695787392
# [190/848] https://lun.ua/realty/4695486935
# [191/848] https://lun.ua/realty/4504151343
# [192/848] https://lun.ua/realty/4683906477
# [193/848] https://lun.ua/realty/4690346649
# [194/848] https://lun.ua/realty/4695873443
# [195/848] https://lun.ua/realty/4696062950
# [196/848] https://lun.ua/realty/4695470340
# [197/848] https://lun.ua/realty/4696139077
# [198/848] https://lun.ua/realty/4695988453
# [199/848] https://lun.ua/realty/4620888659
# [200/848] https://lun.ua/realty/4695896430
# [201/848] https://lun.ua/realty/4387749702
# [202/848] https://lun.ua/realty/4696208006
# [203/848] https://lun.ua/realty/4695907727
# [204/848] https://lun.ua/realty/4695788001
# [205/848] https://lun.ua/realty/4531874949
# [206/848] https://lun.ua/realty/4695860102
# [207/848] https://lun.ua/realty/4695570129
# [208/848] https://lun.ua/realty/4696135159
# [209/848] https://lun.ua/realty/4604022961
# [210/848] https://lun.ua/realty/4696032929
# [211/848] https://lun.ua/realty/4681057854
# [212/848] https://lun.ua/realty/4609759427
# [213/848] https://lun.ua/realty/4692944833
# [214/848] https://lun.ua/realty/4695907685
# [215/848] https://lun.ua/realty/4680632855
# [216/848] https://lun.ua/realty/4695456994
# [217/848] https://lun.ua/realty/4695468140
# [218/848] https://lun.ua/realty/4677033444
# [219/848] https://lun.ua/realty/4695923780
# [220/848] https://lun.ua/realty/4696255396
# [221/848] https://lun.ua/realty/4687715604
# [222/848] https://lun.ua/realty/4695786044
# [223/848] https://lun.ua/realty/4675174347
# [224/848] https://lun.ua/realty/4696203423
# [225/848] https://lun.ua/realty/4617125874
# [226/848] https://lun.ua/realty/4696163633
# [227/848] https://lun.ua/realty/4657287371
# [228/848] https://lun.ua/realty/4696215820
# [229/848] https://lun.ua/realty/4695953659
# [230/848] https://lun.ua/realty/4695695863
# [231/848] https://lun.ua/realty/4469333678
# [232/848] https://lun.ua/realty/4098566135
# [233/848] https://lun.ua/realty/4696375525
# [234/848] https://lun.ua/realty/4696288780
# [235/848] https://lun.ua/realty/4500797117
# [236/848] https://lun.ua/realty/4695814906
# [237/848] https://lun.ua/realty/4618564895
# [238/848] https://lun.ua/realty/4608975244
# [239/848] https://lun.ua/realty/4604686960
# [240/848] https://lun.ua/realty/4695743344
# [241/848] https://lun.ua/realty/4695560014
# [242/848] https://lun.ua/realty/4688313706
# [243/848] https://lun.ua/realty/4667863899
# [244/848] https://lun.ua/realty/3718223590
# [245/848] https://lun.ua/realty/4532511284
# [246/848] https://lun.ua/realty/4695608764
# [247/848] https://lun.ua/realty/4671041618
# [248/848] https://lun.ua/realty/4695518287
# [249/848] https://lun.ua/realty/4696115600
# [250/848] https://lun.ua/realty/4695611578
# [251/848] https://lun.ua/realty/4533288825
# [252/848] https://lun.ua/realty/4695716645
# [253/848] https://lun.ua/realty/4622864000
# [254/848] https://lun.ua/realty/4696348136
# [255/848] https://lun.ua/realty/4695987629
# [256/848] https://lun.ua/realty/4632826216
# [257/848] https://lun.ua/realty/4695909654
# [258/848] https://lun.ua/realty/4695623031
# [259/848] https://lun.ua/realty/4694830732
# [260/848] https://lun.ua/realty/4695087231
# [261/848] https://lun.ua/realty/4695655526
# [262/848] https://lun.ua/realty/4297906288
# [263/848] https://lun.ua/realty/4643746591
# [264/848] https://lun.ua/realty/4696043550
# [265/848] https://lun.ua/realty/4692748727
# [266/848] https://lun.ua/realty/4695460656
# [267/848] https://lun.ua/realty/4696304083
# [268/848] https://lun.ua/realty/4695788002
# [269/848] https://lun.ua/realty/4617249301
# [270/848] https://lun.ua/realty/4696255394
# [271/848] https://lun.ua/realty/4693044982
# [272/848] https://lun.ua/realty/4563613922
# [273/848] https://lun.ua/realty/4695956593
# [274/848] https://lun.ua/realty/4576451464
# [275/848] https://lun.ua/realty/4473413907
# [276/848] https://lun.ua/realty/4643349280
# [277/848] https://lun.ua/realty/4695823777
# [278/848] https://lun.ua/realty/4696255443
# [279/848] https://lun.ua/realty/4695866172
# [280/848] https://lun.ua/realty/4695084705
# [281/848] https://lun.ua/realty/4592225168
# [282/848] https://lun.ua/realty/4695667317
# [283/848] https://lun.ua/realty/4696081888
# [284/848] https://lun.ua/realty/4696068572
# [285/848] https://lun.ua/realty/4636721080
# [286/848] https://lun.ua/realty/4695479332
# [287/848] https://lun.ua/realty/4447584105
# [288/848] https://lun.ua/realty/4696267101
# [289/848] https://lun.ua/realty/4347981658
# [290/848] https://lun.ua/realty/4667490592
# [291/848] https://lun.ua/realty/4417089028
# [292/848] https://lun.ua/realty/4520563446
# [293/848] https://lun.ua/realty/4670786916
# [294/848] https://lun.ua/realty/4671829390
# [295/848] https://lun.ua/realty/4695364481
# [296/848] https://lun.ua/realty/4695488652
# [297/848] https://lun.ua/realty/4696095241
# [298/848] https://lun.ua/realty/4671747119
# [299/848] https://lun.ua/realty/4695882980
# [300/848] https://lun.ua/realty/4580135410
#
# [АВТОЗБЕРЕЖЕННЯ] 300 нових квартир додано у kyiv_flats_data.csv!
#
# [301/848] https://lun.ua/realty/4694846752
# [302/848] https://lun.ua/realty/4604534839
# [303/848] https://lun.ua/realty/4695523944
# [304/848] https://lun.ua/realty/4674437171
# [305/848] https://lun.ua/realty/4695907710
# [306/848] https://lun.ua/realty/4685346741
# [307/848] https://lun.ua/realty/4696299587
# [308/848] https://lun.ua/realty/4391791502
# [309/848] https://lun.ua/realty/4648850526
# [310/848] https://lun.ua/realty/4687921291
# [311/848] https://lun.ua/realty/4680167258
# [312/848] https://lun.ua/realty/4637923046
# [313/848] https://lun.ua/realty/4696285276
# [314/848] https://lun.ua/realty/4584311653
# [315/848] https://lun.ua/realty/4603556483
# [316/848] https://lun.ua/realty/4688461399
# [317/848] https://lun.ua/realty/4695471578
# [318/848] https://lun.ua/realty/4536805978
# [319/848] https://lun.ua/realty/4409749522
# [320/848] https://lun.ua/realty/4679963413
# [321/848] https://lun.ua/realty/4695704906
# [322/848] https://lun.ua/realty/4564671897
# [323/848] https://lun.ua/realty/4696255405
# [324/848] https://lun.ua/realty/3860314483
# [325/848] https://lun.ua/realty/4607871223
# [326/848] https://lun.ua/realty/4653451167
# [327/848] https://lun.ua/realty/4695729488
# [328/848] https://lun.ua/realty/4696106028
# [329/848] https://lun.ua/realty/4635762982
# [330/848] https://lun.ua/realty/4501691011
# [331/848] https://lun.ua/realty/4532983582
# [332/848] https://lun.ua/realty/4694980923
# [333/848] https://lun.ua/realty/4628400818
# [334/848] https://lun.ua/realty/4695506083
# [335/848] https://lun.ua/realty/4383788616
# [336/848] https://lun.ua/realty/4576747636
# [337/848] https://lun.ua/realty/4580186118
# [338/848] https://lun.ua/realty/4696046812
# [339/848] https://lun.ua/realty/4695549586
# Помилка при парсингу https://lun.ua/realty/4695549586: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# [340/848] https://lun.ua/realty/4690146294
# [341/848] https://lun.ua/realty/4695457063
# [342/848] https://lun.ua/realty/4672011646
# [343/848] https://lun.ua/realty/4514085655
# [344/848] https://lun.ua/realty/4696266517
# [345/848] https://lun.ua/realty/4592961417
# [346/848] https://lun.ua/realty/4679747656
# [347/848] https://lun.ua/realty/4573645875
# [348/848] https://lun.ua/realty/4695619093
# [349/848] https://lun.ua/realty/4693638871
# [350/848] https://lun.ua/realty/4696101742
# [351/848] https://lun.ua/realty/4695472210
# [352/848] https://lun.ua/realty/4694961088
# [353/848] https://lun.ua/realty/4695153657
# [354/848] https://lun.ua/realty/4696106851
# [355/848] https://lun.ua/realty/4550083073
# [356/848] https://lun.ua/realty/4695908667
# [357/848] https://lun.ua/realty/4576234620
# [358/848] https://lun.ua/realty/4695469062
# [359/848] https://lun.ua/realty/4647870946
# [360/848] https://lun.ua/realty/4695655540
# [361/848] https://lun.ua/realty/4696095231
# [362/848] https://lun.ua/realty/4695694575
# [363/848] https://lun.ua/realty/4696073354
# [364/848] https://lun.ua/realty/4694951080
# [365/848] https://lun.ua/realty/4696231572
# [366/848] https://lun.ua/realty/4605371387
# [367/848] https://lun.ua/realty/4636243083
# [368/848] https://lun.ua/realty/4695999323
# [369/848] https://lun.ua/realty/4224048367
# [370/848] https://lun.ua/realty/4612061326
# [371/848] https://lun.ua/realty/4696162139
# [372/848] https://lun.ua/realty/4643091728
# [373/848] https://lun.ua/realty/4687902910
# [374/848] https://lun.ua/realty/4696336918
# [375/848] https://lun.ua/realty/4611733911
# [376/848] https://lun.ua/realty/4675778859
# [377/848] https://lun.ua/realty/4248501352
# [378/848] https://lun.ua/realty/4696106871
# [379/848] https://lun.ua/realty/4604347784
# [380/848] https://lun.ua/realty/4696117151
# [381/848] https://lun.ua/realty/4695699808
# [382/848] https://lun.ua/realty/4671602563
# [383/848] https://lun.ua/realty/4591955946
# [384/848] https://lun.ua/realty/4695683044
# [385/848] https://lun.ua/realty/4694965636
# [386/848] https://lun.ua/realty/4695705431
# [387/848] https://lun.ua/realty/4692694927
# [388/848] https://lun.ua/realty/4695622031
# [389/848] https://lun.ua/realty/4695582506
# [390/848] https://lun.ua/realty/4666767744
# [391/848] https://lun.ua/realty/4694784494
# [392/848] https://lun.ua/realty/4620946884
# [393/848] https://lun.ua/realty/4696297643
# [394/848] https://lun.ua/realty/4564092556
# [395/848] https://lun.ua/realty/4025463748
# [396/848] https://lun.ua/realty/4695814820
# [397/848] https://lun.ua/realty/4508299829
# [398/848] https://lun.ua/realty/4695908611
# [399/848] https://lun.ua/realty/4692944813
# [400/848] https://lun.ua/realty/4458840388
# [401/848] https://lun.ua/realty/4511947503
# [402/848] https://lun.ua/realty/4695689678
# [403/848] https://lun.ua/realty/4459064405
# [404/848] https://lun.ua/realty/4660983601
# [405/848] https://lun.ua/realty/4696230587
# [406/848] https://lun.ua/realty/4616346318
# [407/848] https://lun.ua/realty/4682303974
# [408/848] https://lun.ua/realty/428983516
# [409/848] https://lun.ua/realty/4591923972
# [410/848] https://lun.ua/realty/4695717341
# [411/848] https://lun.ua/realty/4532049100
# [412/848] https://lun.ua/realty/4696069948
# [413/848] https://lun.ua/realty/4696070109
# [414/848] https://lun.ua/realty/4242076904
# [415/848] https://lun.ua/realty/4470327919
# [416/848] https://lun.ua/realty/4695787961
# [417/848] https://lun.ua/realty/4694913369
# [418/848] https://lun.ua/realty/4667291710
# [419/848] https://lun.ua/realty/4692693431
# [420/848] https://lun.ua/realty/4695691173
# [421/848] https://lun.ua/realty/4696336220
# [422/848] https://lun.ua/realty/4695849195
# [423/848] https://lun.ua/realty/4695766094
# [424/848] https://lun.ua/realty/4695469063
# [425/848] https://lun.ua/realty/4529364324
# [426/848] https://lun.ua/realty/4695670703
# [427/848] https://lun.ua/realty/4645770892
# [428/848] https://lun.ua/realty/4662541397
# [429/848] https://lun.ua/realty/4101779390
# [430/848] https://lun.ua/realty/4696300910
# [431/848] https://lun.ua/realty/4695542653
# [432/848] https://lun.ua/realty/4670943310
# [433/848] https://lun.ua/realty/4530256534
# [434/848] https://lun.ua/realty/4695945145
# [435/848] https://lun.ua/realty/4695511121
# [436/848] https://lun.ua/realty/4685014239
# [437/848] https://lun.ua/realty/4695225667
# [438/848] https://lun.ua/realty/3265389850
# [439/848] https://lun.ua/realty/4621664399
# [440/848] https://lun.ua/realty/4696186446
# [441/848] https://lun.ua/realty/4695622690
# [442/848] https://lun.ua/realty/4694809010
# [443/848] https://lun.ua/realty/4547590480
# [444/848] https://lun.ua/realty/4478505684
# [445/848] https://lun.ua/realty/4523519935
# [446/848] https://lun.ua/realty/4695705670
# [447/848] https://lun.ua/realty/4288393282
# [448/848] https://lun.ua/realty/4680169759
# [449/848] https://lun.ua/realty/4497789361
# [450/848] https://lun.ua/realty/4648382966
# [451/848] https://lun.ua/realty/4390521789
# [452/848] https://lun.ua/realty/4524147243
# [453/848] https://lun.ua/realty/4454878642
# [454/848] https://lun.ua/realty/4670730400
# [455/848] https://lun.ua/realty/4584125498
# [456/848] https://lun.ua/realty/4572033645
# [457/848] https://lun.ua/realty/4561463215
# [458/848] https://lun.ua/realty/4695897382
# [459/848] https://lun.ua/realty/4004007418
# [460/848] https://lun.ua/realty/4696255411
# [461/848] https://lun.ua/realty/4696070108
# [462/848] https://lun.ua/realty/4688602903
# [463/848] https://lun.ua/realty/4632745086
# [464/848] https://lun.ua/realty/4541530441
# [465/848] https://lun.ua/realty/4695656111
# [466/848] https://lun.ua/realty/4696032132
# [467/848] https://lun.ua/realty/4601127660
# [468/848] https://lun.ua/realty/4621693207
# [469/848] https://lun.ua/realty/4696150377
# [470/848] https://lun.ua/realty/4663231540
# [471/848] https://lun.ua/realty/4680052880
# [472/848] https://lun.ua/realty/4436465018
# [473/848] https://lun.ua/realty/4695565470
# [474/848] https://lun.ua/realty/4696186934
# [475/848] https://lun.ua/realty/4695622716
# [476/848] https://lun.ua/realty/4696373055
# [477/848] https://lun.ua/realty/4694974965
# [478/848] https://lun.ua/realty/4450792410
# [479/848] https://lun.ua/realty/4696314471
# [480/848] https://lun.ua/realty/4592599889
# [481/848] https://lun.ua/realty/4696207984
# [482/848] https://lun.ua/realty/4696080656
# [483/848] https://lun.ua/realty/4639370191
# [484/848] https://lun.ua/realty/4690103844
# [485/848] https://lun.ua/realty/1185592253
# [486/848] https://lun.ua/realty/4625209529
# [487/848] https://lun.ua/realty/4649910396
# [488/848] https://lun.ua/realty/4178553562
# [489/848] https://lun.ua/realty/4368914237
# [490/848] https://lun.ua/realty/4535954222
# [491/848] https://lun.ua/realty/4624512273
# [492/848] https://lun.ua/realty/4696215821
# [493/848] https://lun.ua/realty/4520291073
# [494/848] https://lun.ua/realty/3771953629
# [495/848] https://lun.ua/realty/4695472688
# [496/848] https://lun.ua/realty/4424965962
# [497/848] https://lun.ua/realty/4687933316
# [498/848] https://lun.ua/realty/4695705801
# [499/848] https://lun.ua/realty/4695622033
# [500/848] https://lun.ua/realty/4695622038
# [501/848] https://lun.ua/realty/4653392500
# [502/848] https://lun.ua/realty/4532522532
# [503/848] https://lun.ua/realty/4675308824
# [504/848] https://lun.ua/realty/4426430086
# [505/848] https://lun.ua/realty/4548086519
# [506/848] https://lun.ua/realty/4628008182
# [507/848] https://lun.ua/realty/4695622035
# [508/848] https://lun.ua/realty/4696323371
# [509/848] https://lun.ua/realty/4695807441
# [510/848] https://lun.ua/realty/4696046254
# [511/848] https://lun.ua/realty/4625320317
# [512/848] https://lun.ua/realty/4671747087
# [513/848] https://lun.ua/realty/4695743365
# [514/848] https://lun.ua/realty/4695611529
# [515/848] https://lun.ua/realty/4670402807
# [516/848] https://lun.ua/realty/4689255078
# [517/848] https://lun.ua/realty/4695965870
# [518/848] https://lun.ua/realty/4696111966
# [519/848] https://lun.ua/realty/4575219291
# [520/848] https://lun.ua/realty/4666589840
# [521/848] https://lun.ua/realty/4695838291
# [522/848] https://lun.ua/realty/4695559144
# [523/848] https://lun.ua/realty/4695539540
# [524/848] https://lun.ua/realty/4604460989
# [525/848] https://lun.ua/realty/4695456818
# [526/848] https://lun.ua/realty/2709873295
# [527/848] https://lun.ua/realty/4249342557
# [528/848] https://lun.ua/realty/4695502661
# [529/848] https://lun.ua/realty/4684283038
# [530/848] https://lun.ua/realty/4687678556
# [531/848] https://lun.ua/realty/4696266525
# [532/848] https://lun.ua/realty/4552663903
# [533/848] https://lun.ua/realty/4695456700
# [534/848] https://lun.ua/realty/4695728319
# [535/848] https://lun.ua/realty/4695988439
# [536/848] https://lun.ua/realty/4694784497
# [537/848] https://lun.ua/realty/4696257240
# [538/848] https://lun.ua/realty/3161989502
# [539/848] https://lun.ua/realty/4695878676
# [540/848] https://lun.ua/realty/4587800713
# [541/848] https://lun.ua/realty/4695487102
# [542/848] https://lun.ua/realty/4696148882
# [543/848] https://lun.ua/realty/4498602267
# [544/848] https://lun.ua/realty/4695814818
# [545/848] https://lun.ua/realty/4588956618
# [546/848] https://lun.ua/realty/4695965850
# [547/848] https://lun.ua/realty/4644990555
# [548/848] https://lun.ua/realty/4490720647
# [549/848] https://lun.ua/realty/4695488653
# [550/848] https://lun.ua/realty/4696010175
# [551/848] https://lun.ua/realty/4394353693
# [552/848] https://lun.ua/realty/4695529936
# [553/848] https://lun.ua/realty/4696080663
# [554/848] https://lun.ua/realty/4695502693
# [555/848] https://lun.ua/realty/4696201638
# [556/848] https://lun.ua/realty/4689491101
# [557/848] https://lun.ua/realty/4384384051
# [558/848] https://lun.ua/realty/4576584562
# [559/848] https://lun.ua/realty/4690388465
# [560/848] https://lun.ua/realty/4551890524
# [561/848] https://lun.ua/realty/4662930360
# [562/848] https://lun.ua/realty/4695622037
# [563/848] https://lun.ua/realty/4639773072
# [564/848] https://lun.ua/realty/4682920156
# [565/848] https://lun.ua/realty/4370883431
# [566/848] https://lun.ua/realty/4695908693
# [567/848] https://lun.ua/realty/4695456921
# [568/848] https://lun.ua/realty/4652477012
# [569/848] https://lun.ua/realty/4696169623
# [570/848] https://lun.ua/realty/4616635617
# [571/848] https://lun.ua/realty/4695744351
# [572/848] https://lun.ua/realty/4640354847
# [573/848] https://lun.ua/realty/4666421813
# [574/848] https://lun.ua/realty/4561768749
# [575/848] https://lun.ua/realty/4667116023
# [576/848] https://lun.ua/realty/4568509782
# [577/848] https://lun.ua/realty/4695803179
# [578/848] https://lun.ua/realty/4695882965
# [579/848] https://lun.ua/realty/4666705179
# [580/848] https://lun.ua/realty/4644012326
# [581/848] https://lun.ua/realty/4620794405
# [582/848] https://lun.ua/realty/4696069993
# [583/848] https://lun.ua/realty/4604374798
# [584/848] https://lun.ua/realty/4694784498
# [585/848] https://lun.ua/realty/4695896279
# [586/848] https://lun.ua/realty/4695988452
# [587/848] https://lun.ua/realty/4595874473
# [588/848] https://lun.ua/realty/4675350812
# [589/848] https://lun.ua/realty/4533214267
# [590/848] https://lun.ua/realty/4696186431
# [591/848] https://lun.ua/realty/4696082720
# [592/848] https://lun.ua/realty/4692743838
# [593/848] https://lun.ua/realty/4696102474
# [594/848] https://lun.ua/realty/4670802242
# [595/848] https://lun.ua/realty/4692383103
# [596/848] https://lun.ua/realty/4696057289
# [597/848] https://lun.ua/realty/4695896514
# [598/848] https://lun.ua/realty/4679837243
# [599/848] https://lun.ua/realty/4591955944
# [600/848] https://lun.ua/realty/4696231323
# [601/848] https://lun.ua/realty/4405536378
#
# [АВТОЗБЕРЕЖЕННЯ] 300 нових квартир додано у kyiv_flats_data.csv!
#
# [602/848] https://lun.ua/realty/4696081244
# [603/848] https://lun.ua/realty/4695549585
# [604/848] https://lun.ua/realty/4675308286
# [605/848] https://lun.ua/realty/4360360200
# [606/848] https://lun.ua/realty/4676466138
# [607/848] https://lun.ua/realty/4695549816
# [608/848] https://lun.ua/realty/4636549802
# [609/848] https://lun.ua/realty/4696128526
# [610/848] https://lun.ua/realty/4696186403
# [611/848] https://lun.ua/realty/4645836398
# [612/848] https://lun.ua/realty/4557072346
# [613/848] https://lun.ua/realty/4462045776
# [614/848] https://lun.ua/realty/4652773193
# [615/848] https://lun.ua/realty/4450307324
# [616/848] https://lun.ua/realty/4471532786
# [617/848] https://lun.ua/realty/4695610210
# [618/848] https://lun.ua/realty/4696069201
# [619/848] https://lun.ua/realty/4696157162
# [620/848] https://lun.ua/realty/4665247618
# [621/848] https://lun.ua/realty/4695950346
# [622/848] https://lun.ua/realty/4688077249
# [623/848] https://lun.ua/realty/4695743979
# [624/848] https://lun.ua/realty/4695989651
# [625/848] https://lun.ua/realty/4695469023
# [626/848] https://lun.ua/realty/4696208514
# [627/848] https://lun.ua/realty/4617573034
# [628/848] https://lun.ua/realty/4696163646
# [629/848] https://lun.ua/realty/4696074167
# [630/848] https://lun.ua/realty/4636756763
# [631/848] https://lun.ua/realty/4695469034
# [632/848] https://lun.ua/realty/4584152516
# [633/848] https://lun.ua/realty/4695919051
# [634/848] https://lun.ua/realty/3066503033
# [635/848] https://lun.ua/realty/4521112430
# [636/848] https://lun.ua/realty/4528963258
# [637/848] https://lun.ua/realty/4696314474
# [638/848] https://lun.ua/realty/4662686260
# [639/848] https://lun.ua/realty/4695988432
# [640/848] https://lun.ua/realty/4632503500
# [641/848] https://lun.ua/realty/4532502337
# [642/848] https://lun.ua/realty/4519997356
# [643/848] https://lun.ua/realty/4444725003
# [644/848] https://lun.ua/realty/4692101498
# [645/848] https://lun.ua/realty/4351555367
# [646/848] https://lun.ua/realty/4521537793
# [647/848] https://lun.ua/realty/4469566566
# [648/848] https://lun.ua/realty/4648777811
# [649/848] https://lun.ua/realty/4695916967
# [650/848] https://lun.ua/realty/4402258240
# [651/848] https://lun.ua/realty/4696188046
# [652/848] https://lun.ua/realty/4676125170
# [653/848] https://lun.ua/realty/4695743329
# [654/848] https://lun.ua/realty/4682645995
# [655/848] https://lun.ua/realty/4650549695
# [656/848] https://lun.ua/realty/4667124486
# [657/848] https://lun.ua/realty/4398439206
# [658/848] https://lun.ua/realty/4696021676
# [659/848] https://lun.ua/realty/4695457029
# [660/848] https://lun.ua/realty/4654857786
# [661/848] https://lun.ua/realty/4509317989
# [662/848] https://lun.ua/realty/4695814813
# [663/848] https://lun.ua/realty/4596972436
# [664/848] https://lun.ua/realty/4343479342
# [665/848] https://lun.ua/realty/4695930581
# [666/848] https://lun.ua/realty/4497974134
# [667/848] https://lun.ua/realty/4695529848
# [668/848] https://lun.ua/realty/4679037589
# [669/848] https://lun.ua/realty/4611902686
# [670/848] https://lun.ua/realty/4696038457
# [671/848] https://lun.ua/realty/4695698082
# [672/848] https://lun.ua/realty/4688121326
# [673/848] https://lun.ua/realty/4498217777
# [674/848] https://lun.ua/realty/3750446026
# [675/848] https://lun.ua/realty/4696375947
# [676/848] https://lun.ua/realty/4657769962
# [677/848] https://lun.ua/realty/4671591373
# [678/848] https://lun.ua/realty/4617279009
# [679/848] https://lun.ua/realty/4629872651
# [680/848] https://lun.ua/realty/4648241875
# [681/848] https://lun.ua/realty/4696302500
# [682/848] https://lun.ua/realty/4639923380
# [683/848] https://lun.ua/realty/4591577313
# [684/848] https://lun.ua/realty/4643844066
# [685/848] https://lun.ua/realty/4695759223
# [686/848] https://lun.ua/realty/4587981953
# [687/848] https://lun.ua/realty/4695549615
# [688/848] https://lun.ua/realty/4666303870
# [689/848] https://lun.ua/realty/4695481850
# [690/848] https://lun.ua/realty/4696206327
# [691/848] https://lun.ua/realty/4695838293
# [692/848] https://lun.ua/realty/4592762738
# [693/848] https://lun.ua/realty/4696033312
# [694/848] https://lun.ua/realty/4632672242
# [695/848] https://lun.ua/realty/4283557897
# [696/848] https://lun.ua/realty/4565477936
# [697/848] https://lun.ua/realty/2752152632
# [698/848] https://lun.ua/realty/4102746171
# [699/848] https://lun.ua/realty/3438331999
# [700/848] https://lun.ua/realty/4670386818
# [701/848] https://lun.ua/realty/4560608475
# [702/848] https://lun.ua/realty/4563642084
# [703/848] https://lun.ua/realty/4318686569
# [704/848] https://lun.ua/realty/4401412145
# [705/848] https://lun.ua/realty/4666094513
# [706/848] https://lun.ua/realty/4675847582
# [707/848] https://lun.ua/realty/4582401854
# [708/848] https://lun.ua/realty/4696254770
# [709/848] https://lun.ua/realty/4365237265
# [710/848] https://lun.ua/realty/4653872089
# [711/848] https://lun.ua/realty/3668701152
# [712/848] https://lun.ua/realty/4695567785
# [713/848] https://lun.ua/realty/4696047213
# [714/848] https://lun.ua/realty/4696079473
# [715/848] https://lun.ua/realty/4696058646
# [716/848] https://lun.ua/realty/4695681034
# [717/848] https://lun.ua/realty/4695570146
# [718/848] https://lun.ua/realty/4644995801
# [719/848] https://lun.ua/realty/4241833204
# [720/848] https://lun.ua/realty/4675912790
# [721/848] https://lun.ua/realty/4152838108
# [722/848] https://lun.ua/realty/4505567692
# [723/848] https://lun.ua/realty/4639742213
# [724/848] https://lun.ua/realty/4648569205
# [725/848] https://lun.ua/realty/4565716529
# [726/848] https://lun.ua/realty/4371394412
# [727/848] https://lun.ua/realty/4398553050
# [728/848] https://lun.ua/realty/4693613398
# [729/848] https://lun.ua/realty/4695988957
# [730/848] https://lun.ua/realty/4417961300
# [731/848] https://lun.ua/realty/4696266521
# [732/848] https://lun.ua/realty/4592305705
# [733/848] https://lun.ua/realty/4456777711
# [734/848] https://lun.ua/realty/4623747746
# [735/848] https://lun.ua/realty/4535811003
# [736/848] https://lun.ua/realty/4591710952
# [737/848] https://lun.ua/realty/4695699355
# [738/848] https://lun.ua/realty/4695704910
# [739/848] https://lun.ua/realty/4695979817
# [740/848] https://lun.ua/realty/4568443760
# [741/848] https://lun.ua/realty/4633070173
# [742/848] https://lun.ua/realty/4620537441
# [743/848] https://lun.ua/realty/4387333261
# [744/848] https://lun.ua/realty/4591735731
# [745/848] https://lun.ua/realty/4013817340
# [746/848] https://lun.ua/realty/4580732977
# [747/848] https://lun.ua/realty/4679791870
# [748/848] https://lun.ua/realty/4447292234
# [749/848] https://lun.ua/realty/4639806780
# [750/848] https://lun.ua/realty/4575328162
# [751/848] https://lun.ua/realty/4696266509
# [752/848] https://lun.ua/realty/4696231472
# [753/848] https://lun.ua/realty/4696058721
# [754/848] https://lun.ua/realty/4694992758
# [755/848] https://lun.ua/realty/4572568576
# [756/848] https://lun.ua/realty/4385437817
# [757/848] https://lun.ua/realty/4531894956
# [758/848] https://lun.ua/realty/4675239834
# [759/848] https://lun.ua/realty/4695472633
# [760/848] https://lun.ua/realty/4675439186
# [761/848] https://lun.ua/realty/4377569326
# [762/848] https://lun.ua/realty/4382668460
# [763/848] https://lun.ua/realty/4532527553
# [764/848] https://lun.ua/realty/4560853992
# [765/848] https://lun.ua/realty/4608892478
# [766/848] https://lun.ua/realty/4695483448
# [767/848] https://lun.ua/realty/4696266534
# [768/848] https://lun.ua/realty/4493834519
# [769/848] https://lun.ua/realty/4643628875
# [770/848] https://lun.ua/realty/4696092669
# [771/848] https://lun.ua/realty/4064846076
# [772/848] https://lun.ua/realty/4695622731
# [773/848] https://lun.ua/realty/4696230585
# [774/848] https://lun.ua/realty/4548328894
# [775/848] https://lun.ua/realty/4696348730
# [776/848] https://lun.ua/realty/4696146113
# [777/848] https://lun.ua/realty/4446883881
# [778/848] https://lun.ua/realty/4219869996
# [779/848] https://lun.ua/realty/4695968927
# [780/848] https://lun.ua/realty/4418390778
# [781/848] https://lun.ua/realty/4696302675
# [782/848] https://lun.ua/realty/1178511650
# [783/848] https://lun.ua/realty/4696213987
# [784/848] https://lun.ua/realty/4695456871
# [785/848] https://lun.ua/realty/4609024098
# [786/848] https://lun.ua/realty/4693379628
# [787/848] https://lun.ua/realty/1538921435
# [788/848] https://lun.ua/realty/4685950216
# [789/848] https://lun.ua/realty/4242120303
# [790/848] https://lun.ua/realty/4696081251
# [791/848] https://lun.ua/realty/4549891970
# [792/848] https://lun.ua/realty/4652207959
# [793/848] https://lun.ua/realty/4696060725
# [794/848] https://lun.ua/realty/4695694462
# [795/848] https://lun.ua/realty/4440965048
# [796/848] https://lun.ua/realty/4695487328
# [797/848] https://lun.ua/realty/4696300025
# [798/848] https://lun.ua/realty/4604309918
# [799/848] https://lun.ua/realty/4428677534
# [800/848] https://lun.ua/realty/4692655606
# [801/848] https://lun.ua/realty/4695668938
# [802/848] https://lun.ua/realty/4649168659
# [803/848] https://lun.ua/realty/4450410945
# [804/848] https://lun.ua/realty/4621511212
# [805/848] https://lun.ua/realty/4629150397
# [806/848] https://lun.ua/realty/4695549574
# [807/848] https://lun.ua/realty/4528921915
# [808/848] https://lun.ua/realty/4451026033
# [809/848] https://lun.ua/realty/4409403662
# [810/848] https://lun.ua/realty/4314183965
# [811/848] https://lun.ua/realty/4520105650
# [812/848] https://lun.ua/realty/4696394771
# [813/848] https://lun.ua/realty/4521808615
# [814/848] https://lun.ua/realty/4695941001
# [815/848] https://lun.ua/realty/4696231349
# [816/848] https://lun.ua/realty/4235877321
# [817/848] https://lun.ua/realty/4521874013
# [818/848] https://lun.ua/realty/4695563233
# [819/848] https://lun.ua/realty/4621854568
# [820/848] https://lun.ua/realty/4640428524
# [821/848] https://lun.ua/realty/4652825980
# [822/848] https://lun.ua/realty/4694950815
# [823/848] https://lun.ua/realty/4682628966
# [824/848] https://lun.ua/realty/4648241883
# [825/848] https://lun.ua/realty/4529534395
# [826/848] https://lun.ua/realty/4625284941
# [827/848] https://lun.ua/realty/4463512065
# [828/848] https://lun.ua/realty/4601615397
# [829/848] https://lun.ua/realty/3111161157
# [830/848] https://lun.ua/realty/4695893551
# [831/848] https://lun.ua/realty/4447270224
# [832/848] https://lun.ua/realty/4621683927
# [833/848] https://lun.ua/realty/4696069904
# [834/848] https://lun.ua/realty/4617747874
# [835/848] https://lun.ua/realty/4592599900
# [836/848] https://lun.ua/realty/4676570783
# [837/848] https://lun.ua/realty/4639555730
# [838/848] https://lun.ua/realty/4695705432
# [839/848] https://lun.ua/realty/4612800619
# [840/848] https://lun.ua/realty/4579344784
# [841/848] https://lun.ua/realty/4675906902
# [842/848] https://lun.ua/realty/4133017569
# [843/848] https://lun.ua/realty/4696117128
# [844/848] https://lun.ua/realty/4508538508
# [845/848] https://lun.ua/realty/4603693733
# [846/848] https://lun.ua/realty/4662818780
# [847/848] https://lun.ua/realty/4639721043
# [848/848] https://lun.ua/realty/4043616002
#
# [АВТОЗБЕРЕЖЕННЯ] 247 нових квартир додано у kyiv_flats_data.csv!
#
#
# Збір даних завершено!
#                                 url    price currency  \
# 0  https://lun.ua/realty/4692693468      NaN      NaN
# 1  https://lun.ua/realty/4661904752      NaN      NaN
# 2  https://lun.ua/realty/4692392855      NaN      NaN
# 3  https://lun.ua/realty/4677008472      NaN      NaN
# 4  https://lun.ua/realty/4693824448  34000.0      UAH
#
#                              address  rooms  area_total area_living  \
# 0                                NaN    NaN         NaN         NaN
# 1                                NaN    NaN         NaN         NaN
# 2                                NaN    NaN         NaN         NaN
# 3                                NaN    NaN         NaN         NaN
# 4  Круглоуніверситетська вулиця, 2/1    2.0        51.0           -
#
#   area_kitchen floor  total_floors  build_year   construction_tech  \
# 0          NaN   NaN           NaN         NaN                 NaN
# 1          NaN   NaN           NaN         NaN                 NaN
# 2          NaN   NaN           NaN         NaN                 NaN
# 3          NaN   NaN           NaN         NaN                 NaN
# 4            7     1           5.0      1937.0  цегляна технологія
#
#               heating_type        lat       lon    district commission  \
# 0                      NaN        NaN       NaN         NaN        NaN
# 1                      NaN        NaN       NaN         NaN        NaN
# 2                      NaN        NaN       NaN         NaN        NaN
# 3                      NaN        NaN       NaN         NaN        NaN
# 4  централізоване опалення  50.442864  30.52381  Печерський        NaN
#
#                                          description
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Квартира має роздільне планування та суміщений...
